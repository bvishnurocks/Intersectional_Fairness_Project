# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/Users/koushikmannam/Documents/Intersectional_Fairness_Project/datasets/compas_processed.csv')

# Print the column names
print("Columns in the dataset:")
print(df.columns.tolist())
# Out:
# Columns in the dataset:
# ...
